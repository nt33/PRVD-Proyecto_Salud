# %% [markdown]
# ## Preprocesado de delimitaciones municipales y comarcales
#
# Este notebook se centra en la **carga y preprocesado de las delimitaciones territoriales** de los municipios y comarcas de la Comunitat Valenciana.
#
# El objetivo es preparar las geometrías y la información territorial asociada para su uso en análisis espaciales y representación cartográfica, así como para su integración con los datos demográficos y sanitarios del proyecto.
#
#
# - Datos abiertos de la Generalitat Valenciana – Delimitaciones municipales y comarcales

# %%
import pandas as pd

# %% [markdown]
# ### Carga de datos y exploración inicial

# %%
comarca_datos = pd.read_csv('../datos_raw/GVA-municipios-delimitaciones.csv', sep=',')

# %%
comarca_datos
# Out:
#                                                    WKT   id  cod_ine_mun  \
# 0    MULTIPOLYGON (((713525.146941122 4419313.16997...    0        12081
# 1    MULTIPOLYGON (((740089.287874877 4288689.60805...    1         3027
# 2    MULTIPOLYGON (((728542.211604733 4411582.20513...    2        12018
# 3    MULTIPOLYGON (((688326.189270605 4417120.31115...    3        12022
# 4    MULTIPOLYGON (((742780.180613691 4312185.55242...    4        46187
# ..                                                 ...  ...          ...
# 537  MULTIPOLYGON (((717104.043250278 4351477.45112...  537        46031
# 538  MULTIPOLYGON (((702333.054393397 4328995.60945...  538        46107
# 539  MULTIPOLYGON (((686395.51728084 4251096.003179...  539         3089
# 540  MULTIPOLYGON (((689973.260835391 4229818.12367...  540         3059
# 541  MULTIPOLYGON (((732348.125642551 4421156.09812...  541        12057
#
#      cod_ine_mun_d  cod_catastro          nom_mun      nom_mun_cas  \
# 0           120810         12081          Navajas          Navajas
# 1            30279          3027         Beniardà         Beniardà
# 2           120189         12018          Azuébar          Azuébar
# 3           120228         12022            Bejís            Bejís
# 4           461878         46189  Palma de Gandía  Palma de Gandía
# ..             ...           ...              ...              ...
# 537         460312         46031          Alginet          Alginet
# 538         461075         46109           Chella           Chella
# 539          30895          3089          Monòver          Monóvar
# 540          30591          3059       Crevillent       Crevillent
# 541         120574         12057           Eslida           Eslida
#
#        nom_mun_cas_a      nom_mun_val    nom_mun_val_a         noms_mun  \
# 0            Navajas          Navajas          Navajas          Navajas
# 1           Beniardà         Beniardà         Beniardà         Beniardà
# 2            Azuébar          Azuébar          Azuébar          Azuébar
# 3              Bejís            Bejís            Bejís            Bejís
# 4    Palma de Gandía  Palma de Gandía  Palma de Gandía  Palma de Gandía
# ..               ...              ...              ...              ...
# 537          Alginet          Alginet          Alginet          Alginet
# 538           Chella           Chella           Chella           Chella
# 539          Monóvar          Monòver          Monòver  Monòver/Monóvar
# 540       Crevillent       Crevillent       Crevillent       Crevillent
# 541           Eslida           Eslida           Eslida           Eslida
#
#                                  comarca           provincia  perimetro  \
# 0                       El Alto Palancia  Castelló/Castellón    10747.1
# 1                        la Marina Baixa    Alacant/Alicante    21113.6
# 2                       El Alto Palancia  Castelló/Castellón    22457.2
# 3                       El Alto Palancia  Castelló/Castellón    29091.3
# 4                               la Safor   València/Valencia    26952.9
# ..                                   ...                 ...        ...
# 537                       la Ribera Alta   València/Valencia    22079.2
# 538                 La Canal de Navarrés   València/Valencia    41008.2
# 539  el Vinalopó Mitjà/El Vinalopó Medio    Alacant/Alicante    54834.8
# 540                     el Baix Vinalopó    Alacant/Alicante    51137.5
# 541                       la Plana Baixa  Castelló/Castellón    18851.7
#
#       area_ha
# 0      788.86
# 1     1575.02
# 2     2341.13
# 3     4235.76
# 4     1391.55
# ..        ...
# 537   2408.31
# 538   4350.03
# 539  15225.76
# 540  10456.07
# 541   1813.41
#
# [542 rows x 15 columns]
