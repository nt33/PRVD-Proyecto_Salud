# %% [markdown]
# ## Preprocesado de datos de centros sanitarios
#
# Este notebook se dedica a la **carga y preprocesado de los datos de centros sanitarios** de la Comunitat Valenciana.
#
# El objetivo es limpiar, estructurar y preparar la información de localización y características básicas de los centros sanitarios (nombre, municipio, carácter público o privado y coordenadas geográficas) para su posterior integración con los datos demográficos y territoriales del proyecto.
#
#
# - Datos abiertos de la Generalitat Valenciana – Centros sanitarios

# %%
import pandas as pd

# %%
centros_datos = pd.read_csv('../raw_data/BancoDeDatos-centros-sanitarios.csv', sep=',')

# %%
centros_datos
# Out:
#                                            WKT   id  codigo_centro  \
# 0    POINT (724075.757613561 4367110.78276053)    1              0
# 1    POINT (723779.890457431 4372212.18423382)    2           3048
# 2      POINT (744488.89558615 4267525.0502999)    3           1229
# 3    POINT (684187.785188543 4215018.56524774)    4              0
# 4    POINT (727946.421135555 4371650.09685971)    5              0
# ..                                         ...  ...            ...
# 147  POINT (725797.615462709 4369297.22313886)  148          90400
# 148  POINT (725797.615462709 4369297.22313886)  149          90400
# 149  POINT (725797.615462709 4369297.22313886)  150          90400
# 150          POINT (725804.0 4369293.99948515)  151          90400
# 151          POINT (725804.0 4369293.99948515)  152          90400
#
#                                          nombre_centro  \
# 0                          CENTRO DE SALUD DE PAIPORTA
# 1                 CENTRO DE SALUD VALENCIA - NOU MOLES
# 2     HOSPITAL UNIVERSITARIO MARINA BAIXA DE LA VIL...
# 3                         ACUÉRDATE DE MÍ AFA BIGASTRO
# 4                                     ASOCIACIÓN ACOVA
# ..                                                 ...
# 147         HOSPITAL UNIVERSITARIO Y POLITÉCNICO LA FE
# 148         HOSPITAL UNIVERSITARIO Y POLITÉCNICO LA FE
# 149         HOSPITAL UNIVERSITARIO Y POLITÉCNICO LA FE
# 150  HOSPITAL UNIVERSITARIO Y POLITÉCNICO LA FE-FUN...
# 151  HOSPITAL UNIVERSITARIO Y POLITÉCNICO LA FE-FUN...
#
#                                     nombre_certificado  \
# 0        ACREDITACIÓN FASE 4D DEL PROGRAMA IHAN UNICEF
# 1        ACREDITACIÓN FASE 4D DEL PROGRAMA IHAN UNICEF
# 2                                        ISO 9001:2015
# 3                                        ISO 9001:2015
# 4                                        ISO 9001:2015
# ..                                                 ...
# 147  ACREDITACIÓN COMO UNIDAD DE ALTA COMPLEJIDAD C...
# 148  ACREDITACIÓN COMO UNIDAD DE ALTA COMPLEJIDAD C...
# 149  UNE-EN ISO 15189:2023 LABORATORIOS CLÍNICOS. R...
# 150  UNE 179007:2013-SERVICIOS SANITARIOS. SISTEMAS...
# 151                                      ISO 9001:2015
#
#                                    alcance_certificado fecha_caducidad  \
# 0                   Atención al nacimiento y lactancia      2026-01-30
# 1                   Atención al nacimiento y lactancia      2026-01-30
# 2    FASE PREANALÍTICA, ANALÍTICA Y POSTANALÍTICA D...      2026-02-13
# 3    UNIDAD DE RESPIRO PARA LA PRESTACIÓN DE SERVIC...      2027-08-20
# 4    PRESTACIÓN DE SERVICIOS DESTINADOS EN CENTRO D...      2026-06-19
# ..                                                 ...             ...
# 147             UNIDAD DE ASMA- SERVICIO DE NEUMOLOGÍA      2030-06-30
# 148            UNIDAD DEL SUEÑO-SERVICIO DE NEUMOLOGÍA      2030-06-30
# 149  UNIDAD DE BIOLOGÍA MOLECULAR- SERVICIO DE ANÁL...             NaN
# 150  PRESTACIÓN DE SERVICIOS SANITARIOS DE REPRODUC...      2028-06-03
# 151  PRESTACIÓN DE SERVICIOS SANITARIOS DE REPRODUC...      2028-06-21
#
#     localidad                    municipio     cp publico  longitud    latitud
# 0    Valencia                     Paiporta  46200      Sí -0.396824  39.424422
# 1    Valencia                     Valencia  46018      Sí -0.398549  39.470419
# 2    Alicante  Villajoyosa/Vila Joiosa, la   3570      Sí -0.195538  38.522560
# 3    Alicante                     Bigastro   3380      Sí -0.900408  38.064192
# 4    Valencia                     Valencia  46023      No -0.350353  39.464266
# ..        ...                          ...    ...     ...       ...        ...
# 147  Valencia                     Valencia  46026      Sí -0.376102  39.443654
# 148  Valencia                     Valencia  46026      Sí -0.376102  39.443654
# 149  Valencia                     Valencia  46026      Sí -0.376102  39.443654
# 150  Valencia                     Valencia  46026      Sí -0.376029  39.443623
# 151  Valencia                     Valencia  46026      Sí -0.376029  39.443623
#
# [152 rows x 13 columns]
