# %% [markdown]
# https://datos.gob.es/es/catalogo/l02000012-centros-sanitarios1

# %%
import pandas as pd

# %%
centros_datos = pd.read_csv('../datos_raw/BancoDeDatos-centros-sanitarios.csv', sep=';')

# %%
centros_datos
# Out:
#      objectid     id  fase  cod_agrupa                      fecha  cod_mun  \
# 0          21  392.0  2021         NaN                        NaN    12013
# 1          51  360.0  2021         NaN                        NaN    12136
# 2          53  364.0  2021         NaN                        NaN    12140
# 3           5  324.0  2021         NaN                        NaN    12092
# 4          20  391.0  2021         NaN                        NaN    12012
# ..        ...    ...   ...         ...                        ...      ...
# 121        94  306.0  2021         NaN                        NaN    12067
# 122       107  332.0  2021         NaN                        NaN    12100
# 123       111  354.0  2021         NaN                        NaN    12128
# 124       120  345.0  2021         NaN                        NaN    12120
# 125       445    NaN  2021         NaN  2018-12-26T01:00:00+00:00    12009
#
# ...
