# %% [markdown]
# ## Preprocesado de datos de centros sanitarios
#
# Este notebook se dedica a la **carga y preprocesado de los datos de centros sanitarios** de la Comunitat Valenciana.
#
# El objetivo es limpiar, estructurar y preparar la información de localización y características básicas de los centros sanitarios (nombre, municipio, carácter público o privado y coordenadas geográficas) para su posterior integración con los datos demográficos y territoriales del proyecto.
#
#
# - Datos abiertos de la Generalitat Valenciana – Centros sanitarios

# %%
import pandas as pd

# %% [markdown]
# ### Carga de datos y exploración inicial

# %% [markdown]
# #### Carga de los datasets de centros sanitarios
#
# Se cargan de forma independiente los tres conjuntos de datos del Sistema Valenciano de Salud
# (hospitales, centros de salud y centros de especialidades), que posteriormente se integrarán
# en un único dataset.

# %%
# Crear 3 dataframes de centros sanitarios
hospitales_raw = pd.read_csv('../data/raw/GVA-hospitales.csv', sep=',')
centros_salud_raw = pd.read_csv('../data/raw/GVA-centros-de-salud.csv', sep=',')
centros_especialidades_raw = pd.read_csv('../data/raw/GVA-centros-de-especialidades.csv', sep=',')

# %% [markdown]
# #### Comprobaciones iniciales
#
# Antes de integrar los datasets, se revisan sus dimensiones y la coherencia de sus estructuras,
# verificando que todos comparten el mismo esquema de variables.

# %%
# Dimensión de datasets
print(hospitales_raw.shape)
print(centros_salud_raw.shape)
print(centros_especialidades_raw.shape)
# Out:
# (35, 21)
# (248, 21)
# (26, 21)

# %%
# Comprobar que las columnas son las mismas en los 3 datasets
print(all(hospitales_raw.columns == centros_salud_raw.columns) and all(hospitales_raw.columns == centros_especialidades_raw.columns))
print(hospitales_raw.columns)
# Out:
# True
# Index(['WKT', 'id', 'id_interno', 'cen_cod', 'cen_desclar', 'cod_ine_mun',
#        'municipio', 'provincia', 'cen_nombcall', 'cen_numcall', 'cen_codpos',
#        'tce_codi', 'codigo_departamento', 'nombre_departamento', 'codigo_zona',
#        'nombre_zona', 'cen_feci', 'x_coord', 'y_coord', 'tipo', 'tipo_val'],
#       dtype='object')

# %% [markdown]
# #### Integración y exploración inicial
#
# Una vez verificada la compatibilidad de los tres datasets, se concatenan en un único dataframe
# que recoge la totalidad de centros sanitarios del Sistema Valenciano de Salud.
# Sobre este conjunto integrado se realiza una primera exploración descriptiva.

# %%
# Concatenar los 3 dataframes en uno solo
centros_raw = pd.concat([hospitales_raw, centros_salud_raw, centros_especialidades_raw], ignore_index=True)

# %%
# Dimension del dataframe combinado
centros_raw.shape
# Out:
# (309, 21)

# %%
# Valores nulos por columna
centros_raw.isna().sum()
# Out:
# WKT                      0
# id                       0
# id_interno               0
# cen_cod                  0
# cen_desclar              0
# cod_ine_mun              0
# municipio                0
# provincia                0
# cen_nombcall             0
# cen_numcall              8
# cen_codpos               0
# tce_codi                 0
# codigo_departamento      0
# nombre_departamento      6
# codigo_zona              0
# nombre_zona             61
# cen_feci               309
# x_coord                  0
# y_coord                  0
# tipo                     0
# tipo_val                 0
# dtype: int64

# %%
# Número de centros por tipo
centros_raw['tipo'].value_counts()
# Out:
# tipo
# Centros de salud             248
# Hospitales                    35
# Centros de especialidades     26
# Name: count, dtype: int64

# %%
# Número de municipios distintos
centros_raw['cod_ine_mun'].nunique()
# Out:
# 168

# %%
# Descripción estadística del dataset
centros_raw.describe(include='all')
# Out:
#                                        WKT          id     id_interno  \
# count                                  309  309.000000     309.000000
# unique                                 308         NaN            NaN
# top     POINT (715662.76062 4253467.08584)         NaN            NaN
# freq                                     2         NaN            NaN
# mean                                   NaN  155.000000  186700.268608
# std                                    NaN   89.344838   76988.940700
# min                                    NaN    1.000000   26157.000000
# 25%                                    NaN   78.000000  224699.000000
# 50%                                    NaN  155.000000  224776.000000
# 75%                                    NaN  232.000000  224853.000000
# max                                    NaN  309.000000  224930.000000
#
#              cen_cod                       cen_desclar   cod_ine_mun  \
# count     309.000000                               309    309.000000
# unique           NaN                               309           NaN
# top              NaN  HOSPITAL PSIQUIATRICO PROVINCIAL           NaN
# freq             NaN                                 1           NaN
# mean     1101.731392                               NaN  26480.155340
# std      5194.319517                               NaN  20264.201041
# min         2.000000                               NaN   3002.000000
# 25%       233.000000                               NaN   3102.000000
# 50%       457.000000                               NaN  46007.000000
# 75%       959.000000                               NaN  46184.000000
# max     90400.000000                               NaN  46258.000000
#
#        municipio          provincia  cen_nombcall cen_numcall  ...  \
# count        309                309           309         301  ...
# unique       168                  3           294          77  ...
# top     València  València/Valencia  AUSIAS MARCH         S/N  ...
# freq          42                157             3         116  ...
# mean         NaN                NaN           NaN         NaN  ...
# std          NaN                NaN           NaN         NaN  ...
# min          NaN                NaN           NaN         NaN  ...
# 25%          NaN                NaN           NaN         NaN  ...
# 50%          NaN                NaN           NaN         NaN  ...
# 75%          NaN                NaN           NaN         NaN  ...
# max          NaN                NaN           NaN         NaN  ...
#
#           tce_codi  codigo_departamento  nombre_departamento  codigo_zona  \
# count   309.000000           309.000000                  303   309.000000
# unique         NaN                  NaN                   24          NaN
# top            NaN                  NaN            CASTELLON          NaN
# freq           NaN                  NaN                   27          NaN
# mean      3.650485            10.951456                  NaN  1100.864078
# std       5.357436             6.806288                  NaN   679.854153
# min       1.000000             0.000000                  NaN     0.000000
# 25%       1.000000             5.000000                  NaN   509.000000
# 50%       1.000000            11.000000                  NaN  1100.000000
# 75%       1.000000            17.000000                  NaN  1700.000000
# max      15.000000            24.000000                  NaN  2406.000000
#
#                    nombre_zona cen_feci        x_coord       y_coord  \
# count                      248      0.0     309.000000  3.090000e+02
# unique                     226      NaN            NaN           NaN
# top     SANT AGUSTI (CASTELLO)      NaN            NaN           NaN
# freq                         3      NaN            NaN           NaN
# mean                       NaN      NaN  723065.939569  4.469957e+06
# std                        NaN      NaN   23752.249734  2.281538e+06
# min                        NaN      NaN  646247.848321  4.198385e+06
# 25%                        NaN      NaN  709674.948963  4.278917e+06
# 50%                        NaN      NaN  722937.129818  4.365239e+06
# 75%                        NaN      NaN  734766.742090  4.382127e+06
# max                        NaN      NaN  794604.052674  4.442719e+07
#
#                     tipo          tipo_val
# count                309               309
# unique                 3                 3
# top     Centros de salud  Centres de salut
# freq                 248               248
# mean                 NaN               NaN
# std                  NaN               NaN
# min                  NaN               NaN
# 25%                  NaN               NaN
# 50%                  NaN               NaN
# 75%                  NaN               NaN
# max                  NaN               NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# Se observa que el dataset final incluye centros sanitarios distribuidos en un número amplio
# de municipios de la Comunitat Valenciana, lo que permite un análisis territorial consistente.

# %%
# Vista previa del dataframe
centros_raw.sample(5)
# Out:
#                                     WKT   id  id_interno  cen_cod  \
# 132   POINT (706773.40004 4359323.4039)   98      224780      277
# 130  POINT (715761.42382 4341907.56194)   96      224778      327
# 300   POINT (717882.61492 4371178.2728)  301       26176      965
# 219  POINT (680812.17785 4217351.22822)  185      224867      567
# 268   POINT (736736.90402 4339424.6766)  234      224916     2731
#
#                             cen_desclar  cod_ine_mun   municipio  \
# 132       CENTRO DE SALUD DE MONTSERRAT        46172  Montserrat
# 130                        CS L ALCUDIA        46019   l'Alcúdia
# 300  CENTRO DE ESPECIALIDADES DE ALDAIA        46021      Aldaia
# 219                 CS ORIHUELA ALVAREZ         3099    Orihuela
# 268                  C.S. CULLERA RAVAL        46105     Cullera
#
#              provincia                cen_nombcall cen_numcall  ...  tce_codi  \
# 132  València/Valencia                    BON AIRE          18  ...         1
# 130  València/Valencia   ESQ. BOLLENE CON MAGUNCIA         S/N  ...         1
# 300  València/Valencia                   3 D'ABRIL           1  ...        15
# 219   Alacant/Alicante  AVDA. PRINCIPE DE ASTURIAS         S/N  ...         1
# 268  València/Valencia                    VALENCIA         119  ...         1
#
#      codigo_departamento        nombre_departamento codigo_zona  \
# 132                    9  VALENCIA HOSPITAL GENERAL         903
# 130                   11                  LA RIBERA        1104
# 300                   23                    MANISES        2300
# 219                   21                   ORIHUELA        2107
# 268                   11                  LA RIBERA        1110
#
#                           nombre_zona cen_feci        x_coord       y_coord  \
# 132                        MONTSERRAT      NaN  706773.400042  4.359323e+06
# 130                         L'ALCUDIA      NaN  715761.423822  4.341908e+06
# 300                               NaN      NaN  717882.614921  4.371178e+06
# 219  ORIHUELA 2 DR ALVAREZ DE LA RIVA      NaN  680812.177846  4.217351e+06
# 268                           CULLERA      NaN  736736.904019  4.339425e+06
#
#                           tipo                 tipo_val
# 132           Centros de salud         Centres de salut
# 130           Centros de salud         Centres de salut
# 300  Centros de especialidades  Centres d'especialitats
# 219           Centros de salud         Centres de salut
# 268           Centros de salud         Centres de salut
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Análisis exploratorio y preparación de variables

# %%
# Ver filas con wkt duplicados
centros_raw[centros_raw.duplicated(subset=['WKT'], keep=False)]
# Out:
#                                     WKT   id  id_interno  cen_cod  \
# 284  POINT (715662.76062 4253467.08584)  285       26158     4138
# 305  POINT (715662.76062 4253467.08584)  306       26181     2753
#
#                                            cen_desclar  cod_ine_mun  \
# 284  CENTRO DE ESPECIALIDADES SANT VICENT DEL RASPE...         3122
# 305                           C.E. DE SAN VTE. RASPEIG         3122
#
#                                            municipio         provincia  \
# 284  Sant Vicent del Raspeig/San Vicente del Raspeig  Alacant/Alicante
# 305  Sant Vicent del Raspeig/San Vicente del Raspeig  Alacant/Alicante
#
#     cen_nombcall cen_numcall  ...  tce_codi  codigo_departamento  \
# 284   LILLO JUAN         137  ...        15                   19
# 305   LILLO JUAN         137  ...        15                   19
#
#      nombre_departamento codigo_zona  nombre_zona cen_feci        x_coord  \
# 284             ALICANTE        1900          NaN      NaN  715662.760623
# 305             ALICANTE        1900          NaN      NaN  715662.760623
#
#           y_coord                       tipo                 tipo_val
# 284  4.253467e+06  Centros de especialidades  Centres d'especialitats
# 305  4.253467e+06  Centros de especialidades  Centres d'especialitats
#
# [2 rows x 21 columns]
